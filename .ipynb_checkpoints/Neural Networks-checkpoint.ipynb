# %% [markdown]
# # Deep Learning Project

# %% [markdown]
# ## Data

# %%
import pandas as pd

# %%
data_info = pd.read_csv('data/lending_club_info.csv',index_col='LoanStatNew')

# %%
print(data_info.loc['revol_util']['Description'])
# Out:
# Revolving line utilization rate, or the amount of credit the borrower is using relative to all available revolving credit.

# %%
def feat_info(col_name):
    print(data_info.loc[col_name]['Description'])

# %%
feat_info('mort_acc')
# Out:
# Number of mortgage accounts.

# %% [markdown]
# ## More imports and reading in data

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# might be needed depending on your version of Jupyter
# %matplotlib inline

# %%
df = pd.read_csv('data/lending_club_loan_two.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396030 entries, 0 to 396029
# Data columns (total 27 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   loan_amnt             396030 non-null  float64
#  1   term                  396030 non-null  object
#  2   int_rate              396030 non-null  float64
#  3   installment           396030 non-null  float64
#  4   grade                 396030 non-null  object
#  5   sub_grade             396030 non-null  object
#  6   emp_title             373103 non-null  object
#  7   emp_length            377729 non-null  object
#  8   home_ownership        396030 non-null  object
#  9   annual_inc            396030 non-null  float64
#  10  verification_status   396030 non-null  object
#  11  issue_d               396030 non-null  object
#  12  loan_status           396030 non-null  object
#  13  purpose               396030 non-null  object
#  14  title                 394275 non-null  object
#  15  dti                   396030 non-null  float64
#  16  earliest_cr_line      396030 non-null  object
#  17  open_acc              396030 non-null  float64
#  18  pub_rec               396030 non-null  float64
#  19  revol_bal             396030 non-null  float64
#  20  revol_util            395754 non-null  float64
#  21  total_acc             396030 non-null  float64
#  22  initial_list_status   396030 non-null  object
#  23  application_type      396030 non-null  object
#  24  mort_acc              358235 non-null  float64
#  25  pub_rec_bankruptcies  395495 non-null  float64
#  26  address               396030 non-null  object
# dtypes: float64(12), object(15)
# memory usage: 81.6+ MB

# %% [markdown]
# ## Exploratory Data Analysis

# %%
sns.countplot(x='loan_status', data=df)
# Out:
# <AxesSubplot:xlabel='loan_status', ylabel='count'>

# %%
sns.histplot(x='loan_amnt',bins = 30, data=df)
# Out:
# <AxesSubplot:xlabel='loan_amnt', ylabel='Count'>

# %%
df.corr()
# Out:
#                       loan_amnt  int_rate  installment  annual_inc       dti  \
# loan_amnt              1.000000  0.168921     0.953929    0.336887  0.016636
# int_rate               0.168921  1.000000     0.162758   -0.056771  0.079038
# installment            0.953929  0.162758     1.000000    0.330381  0.015786
# annual_inc             0.336887 -0.056771     0.330381    1.000000 -0.081685
# dti                    0.016636  0.079038     0.015786   -0.081685  1.000000
# open_acc               0.198556  0.011649     0.188973    0.136150  0.136181
# pub_rec               -0.077779  0.060986    -0.067892   -0.013720 -0.017639
# revol_bal              0.328320 -0.011280     0.316455    0.299773  0.063571
# revol_util             0.099911  0.293659     0.123915    0.027871  0.088375
# total_acc              0.223886 -0.036404     0.202430    0.193023  0.102128
# mort_acc               0.222315 -0.082583     0.193694    0.236320 -0.025439
# pub_rec_bankruptcies  -0.106539  0.057450    -0.098628   -0.050162 -0.014558
#
#                       open_acc   pub_rec  revol_bal  revol_util  total_acc  \
# loan_amnt             0.198556 -0.077779   0.328320    0.099911   0.223886
# int_rate              0.011649  0.060986  -0.011280    0.293659  -0.036404
# installment           0.188973 -0.067892   0.316455    0.123915   0.202430
# annual_inc            0.136150 -0.013720   0.299773    0.027871   0.193023
# dti                   0.136181 -0.017639   0.063571    0.088375   0.102128
# open_acc              1.000000 -0.018392   0.221192   -0.131420   0.680728
# pub_rec              -0.018392  1.000000  -0.101664   -0.075910   0.019723
# revol_bal             0.221192 -0.101664   1.000000    0.226346   0.191616
# revol_util           -0.131420 -0.075910   0.226346    1.000000  -0.104273
# total_acc             0.680728  0.019723   0.191616   -0.104273   1.000000
# mort_acc              0.109205  0.011552   0.194925    0.007514   0.381072
# pub_rec_bankruptcies -0.027732  0.699408  -0.124532   -0.086751   0.042035
#
#                       mort_acc  pub_rec_bankruptcies
# loan_amnt             0.222315             -0.106539
# int_rate             -0.082583              0.057450
# installment           0.193694             -0.098628
# annual_inc            0.236320             -0.050162
# dti                  -0.025439             -0.014558
# open_acc              0.109205             -0.027732
# pub_rec               0.011552              0.699408
# revol_bal             0.194925             -0.124532
# revol_util            0.007514             -0.086751
# total_acc             0.381072              0.042035
# mort_acc              1.000000              0.027239
# pub_rec_bankruptcies  0.027239              1.000000

# %%
feat_info('pub_rec')
# Out:
# Number of derogatory public records

# %%
fig = plt.figure(figsize=(10,6))
sns.heatmap(df.corr(),cmap='coolwarm',annot=True)
# Out:
# <AxesSubplot:>

# %%
df['installment'].value_counts()
feat_info('installment')
sns.scatterplot(x='installment',y='loan_amnt',data=df)
# Out:
# The monthly payment owed by the borrower if the loan originates.
# <AxesSubplot:xlabel='installment', ylabel='loan_amnt'>

# %%
sns.boxplot(x='loan_status',y='loan_amnt',data=df)
# Out:
# <AxesSubplot:xlabel='loan_status', ylabel='loan_amnt'>

# %%
feat_info('loan_status')
df.groupby('loan_status').describe()
# Out:
# Current status of the loan
#             loan_amnt                                                      \
#                 count          mean          std     min     25%      50%
# loan_status
# Charged Off   77673.0  15126.300967  8505.090557  1000.0  8525.0  14000.0
# Fully Paid   318357.0  13866.878771  8302.319699   500.0  7500.0  12000.0
#
#                                int_rate             ... mort_acc        \
#                  75%      max     count       mean  ...      75%   max
# loan_status                                         ...
# Charged Off  20000.0  40000.0   77673.0  15.882587  ...      2.0  23.0
# Fully Paid   19225.0  40000.0  318357.0  13.092105  ...      3.0  34.0
#
#             pub_rec_bankruptcies
#                            count      mean       std  min  25%  50%  75%  max
# loan_status
# Charged Off              77586.0  0.128412  0.368853  0.0  0.0  0.0  0.0  8.0
# Fully Paid              317909.0  0.119997  0.352992  0.0  0.0  0.0  0.0  8.0
#
# [2 rows x 96 columns]

# %%
df['grade'].unique()
# Out:
# array(['B', 'A', 'C', 'E', 'D', 'F', 'G'], dtype=object)

# %%
df['sub_grade'].unique()
# Out:
# array(['B4', 'B5', 'B3', 'A2', 'C5', 'C3', 'A1', 'B2', 'C1', 'A5', 'E4',
#        'A4', 'A3', 'D1', 'C2', 'B1', 'D3', 'D5', 'D2', 'E1', 'E2', 'E5',
#        'F4', 'E3', 'D4', 'G1', 'F5', 'G2', 'C4', 'F1', 'F3', 'G5', 'G4',
#        'F2', 'G3'], dtype=object)

# %%
sns.countplot(x='grade',hue='loan_status',data=df)
# Out:
# <AxesSubplot:xlabel='grade', ylabel='count'>

# %%
plt.figure(figsize=(12,4))
subgrade_order = sorted(df['sub_grade'].unique())
sns.countplot(x='sub_grade',data=df,order = subgrade_order,palette='coolwarm' )
# Out:
# <AxesSubplot:xlabel='sub_grade', ylabel='count'>

# %%
plt.figure(figsize=(12,4))
sns.countplot(x='sub_grade',data=df,order = subgrade_order,palette='coolwarm',hue='loan_status' )
# Out:
# <AxesSubplot:xlabel='sub_grade', ylabel='count'>

# %%
subdf = df[df['grade']>='F']
ord = sorted(subdf['sub_grade'].unique())
sns.countplot(x='sub_grade',data=subdf,hue='loan_status',order=ord)
# Out:
# <AxesSubplot:xlabel='sub_grade', ylabel='count'>

# %%
df['loan_repaid'] = df['loan_status'].apply(lambda status: int(status=='Fully Paid'))
df[['loan_repaid','loan_status']]
# Out:
#         loan_repaid  loan_status
# 0                 1   Fully Paid
# 1                 1   Fully Paid
# 2                 1   Fully Paid
# 3                 1   Fully Paid
# 4                 0  Charged Off
# ...             ...          ...
# 396025            1   Fully Paid
# 396026            1   Fully Paid
# 396027            1   Fully Paid
# 396028            1   Fully Paid
# 396029            1   Fully Paid
#
# [396030 rows x 2 columns]

# %%
df.corr()['loan_repaid'].drop('loan_repaid',axis=0).sort_values().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Feature Engineering

# %%
def emp_length_splitter(emp_length):
    if(emp_length=='10+ years'):
        return 10
    elif(emp_length=='< 1 year'):
        return 1
    else:
        return emp_length.split()[0]
df['emp_length'] = df['emp_length'].dropna().apply(emp_length_splitter)
sns.countplot(df['emp_length'])
# Out:
# C:\Users\Hovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='emp_length', ylabel='count'>

# %%
df['term']
# Out:
# 0          36 months
# 1          36 months
# 2          36 months
# 3          36 months
# 4          60 months
#              ...
# 396025     60 months
# 396026     36 months
# 396027     36 months
# 396028     60 months
# 396029     36 months
# Name: term, Length: 396030, dtype: object

# %%
#pd.concat([df.drop('term',axis=1),pd.get_dummies(df['term'],drop_first=True)],axis=1)
df['term'] = df['term'].apply(lambda x: 1 if x==' 60 months' else 0)

# %%
df = pd.concat([df.drop('grade',axis=1),pd.get_dummies(df['grade'],drop_first=True)],axis=1)

# %%
df.drop('sub_grade',axis=1,inplace=True)

# %%
feat_info('home_ownership')
# Out:
# The home ownership status provided by the borrower during registration or obtained from the credit report. Our values are: RENT, OWN, MORTGAGE, OTHER

# %%
df = pd.concat([df.drop('home_ownership',axis=1),pd.get_dummies(df['home_ownership'],drop_first=True)],axis=1)

# %%
df = pd.concat([df.drop('verification_status',axis=1),pd.get_dummies(df['verification_status'],drop_first=True)],axis=1)

# %%
df.drop('emp_title',axis=1,inplace=True)

# %%
df['issue_d'] = pd.to_datetime(df['issue_d'])

# %%
df['year'] = df['issue_d'].apply(lambda date:date.year)
df.head()
df.drop('issue_d',axis=1,inplace=True)

# %%
df['title'].unique()
# Out:
# array(['Vacation', 'Debt consolidation', 'Credit card refinancing', ...,
#        'Credit buster ', 'Loanforpayoff', 'Toxic Debt Payoff'],
#       dtype=object)

# %%
df.head()
# Out:
#    loan_amnt  term  int_rate  installment emp_length  annual_inc  loan_status  \
# 0    10000.0     0     11.44       329.48         10    117000.0   Fully Paid
# 1     8000.0     0     11.99       265.68          4     65000.0   Fully Paid
# 2    15600.0     0     10.49       506.97          1     43057.0   Fully Paid
# 3     7200.0     0      6.49       220.65          6     54000.0   Fully Paid
# 4    24375.0     1     17.27       609.33          9     55000.0  Charged Off
#
#               purpose                    title    dti  ...  F  G  MORTGAGE  \
# 0            vacation                 Vacation  26.24  ...  0  0         0
# 1  debt_consolidation       Debt consolidation  22.05  ...  0  0         1
# 2         credit_card  Credit card refinancing  12.79  ...  0  0         0
# 3         credit_card  Credit card refinancing   2.60  ...  0  0         0
# 4         credit_card    Credit Card Refinance  33.95  ...  0  0         1
#
#    NONE  OTHER  OWN RENT Source Verified  Verified  year
# 0     0      0    0    1               0         0  2015
# 1     0      0    0    0               0         0  2015
# 2     0      0    0    1               1         0  2015
# 3     0      0    0    1               0         0  2014
# 4     0      0    0    0               0         1  2013
#
# [5 rows x 36 columns]

# %% [markdown]
# ## Filling Missing Data and Dropping Unnecessary Columns

# %%
len(df)
# Out:
# 396030

# %%
df.isnull().sum()
# Out:
# loan_amnt                   0
# term                        0
# int_rate                    0
# installment                 0
# emp_length              18301
# annual_inc                  0
# loan_status                 0
# purpose                     0
# title                    1755
# dti                         0
# earliest_cr_line            0
# open_acc                    0
# pub_rec                     0
# revol_bal                   0
# revol_util                276
# total_acc                   0
# initial_list_status         0
# application_type            0
# mort_acc                37795
# pub_rec_bankruptcies      535
# address                     0
# loan_repaid                 0
# B                           0
# C                           0
# D                           0
# E                           0
# F                           0
# G                           0
# MORTGAGE                    0
# NONE                        0
# OTHER                       0
# OWN                         0
# RENT                        0
# Source Verified             0
# Verified                    0
# year                        0
# dtype: int64

# %%
df.isnull().sum().apply(lambda x:(x/len(df))*100)
# Out:
# loan_amnt               0.000000
# term                    0.000000
# int_rate                0.000000
# installment             0.000000
# emp_length              4.621115
# annual_inc              0.000000
# loan_status             0.000000
# purpose                 0.000000
# title                   0.443148
# dti                     0.000000
# earliest_cr_line        0.000000
# open_acc                0.000000
# pub_rec                 0.000000
# revol_bal               0.000000
# revol_util              0.069692
# total_acc               0.000000
# initial_list_status     0.000000
# application_type        0.000000
# mort_acc                9.543469
# pub_rec_bankruptcies    0.135091
# address                 0.000000
# loan_repaid             0.000000
# B                       0.000000
# C                       0.000000
# D                       0.000000
# E                       0.000000
# F                       0.000000
# G                       0.000000
# MORTGAGE                0.000000
# NONE                    0.000000
# OTHER                   0.000000
# OWN                     0.000000
# RENT                    0.000000
# Source Verified         0.000000
# Verified                0.000000
# year                    0.000000
# dtype: float64

# %%
df.drop('emp_length',axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# loan_amnt                  0
# term                       0
# int_rate                   0
# installment                0
# annual_inc                 0
# loan_status                0
# purpose                    0
# title                   1755
# dti                        0
# earliest_cr_line           0
# open_acc                   0
# pub_rec                    0
# revol_bal                  0
# revol_util               276
# total_acc                  0
# initial_list_status        0
# application_type           0
# mort_acc                   0
# pub_rec_bankruptcies     535
# address                    0
# loan_repaid                0
# B                          0
# C                          0
# D                          0
# E                          0
# F                          0
# G                          0
# MORTGAGE                   0
# NONE                       0
# OTHER                      0
# OWN                        0
# RENT                       0
# Source Verified            0
# Verified                   0
# year                       0
# dtype: int64

# %%
df['title'].head(10)
# Out:
# 0                   Vacation
# 1         Debt consolidation
# 2    Credit card refinancing
# 3    Credit card refinancing
# 4      Credit Card Refinance
# 5         Debt consolidation
# 6           Home improvement
# 7       No More Credit Cards
# 8         Debt consolidation
# 9         Debt Consolidation
# Name: title, dtype: object

# %%
df.drop('title',axis=1,inplace=True)

# %%
feat_info('mort_acc')
# Out:
# Number of mortgage accounts.

# %%
df['mort_acc'].value_counts()
# Out:
# 0.0     139777
# 1.0      60416
# 2.0      49948
# 3.0      38049
# 4.0      27887
# 5.0      18194
# 6.0      11069
# 7.0       6052
# 8.0       3121
# 9.0       1656
# 10.0       865
# 11.0       479
# 12.0       264
# 13.0       146
# 14.0       107
# 15.0        61
# 16.0        37
# 17.0        22
# 18.0        18
# 19.0        15
# 20.0        13
# 24.0        10
# 22.0         7
# 21.0         4
# 25.0         4
# 27.0         3
# 32.0         2
# 31.0         2
# 23.0         2
# 26.0         2
# 28.0         1
# 30.0         1
# 34.0         1
# Name: mort_acc, dtype: int64

# %%
df.corr()['mort_acc']
# Out:
# loan_amnt               0.222315
# term                    0.096220
# int_rate               -0.082583
# installment             0.193694
# annual_inc              0.236320
# dti                    -0.025439
# open_acc                0.109205
# pub_rec                 0.011552
# revol_bal               0.194925
# revol_util              0.007514
# total_acc               0.381072
# mort_acc                1.000000
# pub_rec_bankruptcies    0.027239
# loan_repaid             0.073111
# B                       0.008494
# C                      -0.026071
# D                      -0.044057
# E                      -0.017311
# F                      -0.011576
# G                      -0.005119
# MORTGAGE                0.476730
# NONE                    0.001501
# OTHER                  -0.001024
# OWN                    -0.065227
# RENT                   -0.447957
# Source Verified        -0.008157
# Verified                0.078095
# year                    0.011220
# Name: mort_acc, dtype: float64

# %%
df.groupby('total_acc').mean()['mort_acc']
# Out:
# total_acc
# 2.0      0.000000
# 3.0      0.052023
# 4.0      0.066743
# 5.0      0.103289
# 6.0      0.151293
#            ...
# 124.0    1.000000
# 129.0    1.000000
# 135.0    3.000000
# 150.0    2.000000
# 151.0    0.000000
# Name: mort_acc, Length: 118, dtype: float64

# %%
total_acc_avg = df.groupby('total_acc').mean()['mort_acc']

# %%
def fill_mort_acc(total_acc,mort_acc):
    '''
    Accepts the total_acc and mort_acc values for the row.
    Checks if the mort_acc is NaN , if so, it returns the avg mort_acc value
    for the corresponding total_acc value for that row.
    
    total_acc_avg here should be a Series or dictionary containing the mapping of the
    groupby averages of mort_acc per total_acc values.
    '''
    if np.isnan(mort_acc):
        return total_acc_avg[total_acc]
    else:
        return mort_acc

# %%
df['mort_acc'] = df.apply(lambda x: fill_mort_acc(x['total_acc'], x['mort_acc']), axis=1)

# %%
df.isnull().sum()
# Out:
# loan_amnt                   0
# term                        0
# int_rate                    0
# installment                 0
# emp_length              18301
# annual_inc                  0
# loan_status                 0
# purpose                     0
# title                    1755
# dti                         0
# earliest_cr_line            0
# open_acc                    0
# pub_rec                     0
# revol_bal                   0
# revol_util                276
# total_acc                   0
# initial_list_status         0
# application_type            0
# mort_acc                    0
# pub_rec_bankruptcies      535
# address                     0
# loan_repaid                 0
# B                           0
# C                           0
# D                           0
# E                           0
# F                           0
# G                           0
# MORTGAGE                    0
# NONE                        0
# OTHER                       0
# OWN                         0
# RENT                        0
# Source Verified             0
# Verified                    0
# year                        0
# dtype: int64

# %%
df.drop('revol_util',axis=1,inplace=True)

# %%
df.drop('pub_rec_bankruptcies',axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# loan_amnt                 0
# term                      0
# int_rate                  0
# installment               0
# annual_inc                0
# loan_status               0
# purpose                   0
# title                  1755
# dti                       0
# earliest_cr_line          0
# open_acc                  0
# pub_rec                   0
# revol_bal                 0
# total_acc                 0
# initial_list_status       0
# application_type          0
# mort_acc                  0
# address                   0
# loan_repaid               0
# B                         0
# C                         0
# D                         0
# E                         0
# F                         0
# G                         0
# MORTGAGE                  0
# NONE                      0
# OTHER                     0
# OWN                       0
# RENT                      0
# Source Verified           0
# Verified                  0
# year                      0
# dtype: int64

# %%
df.columns
# Out:
# Index(['loan_amnt', 'term', 'int_rate', 'installment', 'annual_inc',
#        'loan_status', 'purpose', 'title', 'dti', 'earliest_cr_line',
#        'open_acc', 'pub_rec', 'revol_bal', 'total_acc', 'initial_list_status',
#        'application_type', 'mort_acc', 'address', 'loan_repaid', 'B', 'C', 'D',
#        'E', 'F', 'G', 'MORTGAGE', 'NONE', 'OTHER', 'OWN', 'RENT',
#        'Source Verified', 'Verified', 'year'],
#       dtype='object')

# %%
df = pd.concat([df.drop('application_type',axis=1),pd.get_dummies(df['application_type'],drop_first=True)],axis=1)
df
# Out:
#         loan_amnt  term  int_rate  installment  annual_inc  loan_status  \
# 0         10000.0     0     11.44       329.48    117000.0   Fully Paid
# 1          8000.0     0     11.99       265.68     65000.0   Fully Paid
# 2         15600.0     0     10.49       506.97     43057.0   Fully Paid
# 3          7200.0     0      6.49       220.65     54000.0   Fully Paid
# 4         24375.0     1     17.27       609.33     55000.0  Charged Off
# ...           ...   ...       ...          ...         ...          ...
# 396025    10000.0     1     10.99       217.38     40000.0   Fully Paid
# 396026    21000.0     0     12.29       700.42    110000.0   Fully Paid
# 396027     5000.0     0      9.99       161.32     56500.0   Fully Paid
# 396028    21000.0     1     15.31       503.02     64000.0   Fully Paid
# 396029     2000.0     0     13.61        67.98     42996.0   Fully Paid
#
#                    purpose                    title    dti earliest_cr_line  \
# 0                 vacation                 Vacation  26.24         Jun-1990
# 1       debt_consolidation       Debt consolidation  22.05         Jul-2004
# 2              credit_card  Credit card refinancing  12.79         Aug-2007
# 3              credit_card  Credit card refinancing   2.60         Sep-2006
# 4              credit_card    Credit Card Refinance  33.95         Mar-1999
# ...                    ...                      ...    ...              ...
# 396025  debt_consolidation       Debt consolidation  15.63         Nov-2004
# 396026  debt_consolidation       Debt consolidation  21.45         Feb-2006
# 396027  debt_consolidation     pay off credit cards  17.56         Mar-1997
# 396028  debt_consolidation            Loanforpayoff  15.88         Nov-1990
# 396029  debt_consolidation        Toxic Debt Payoff   8.32         Sep-1998
#
#         ...  MORTGAGE  NONE  OTHER  OWN RENT  Source Verified Verified  year  \
# 0       ...         0     0      0    0    1                0        0  2015
# 1       ...         1     0      0    0    0                0        0  2015
# 2       ...         0     0      0    0    1                1        0  2015
# 3       ...         0     0      0    0    1                0        0  2014
# 4       ...         1     0      0    0    0                0        1  2013
# ...     ...       ...   ...    ...  ...  ...              ...      ...   ...
# 396025  ...         0     0      0    0    1                1        0  2015
# 396026  ...         1     0      0    0    0                1        0  2015
# 396027  ...         0     0      0    0    1                0        1  2013
# 396028  ...         1     0      0    0    0                0        1  2012
# 396029  ...         0     0      0    0    1                0        1  2010
#
#         INDIVIDUAL  JOINT
# 0                1      0
# 1                1      0
# 2                1      0
# 3                1      0
# 4                1      0
# ...            ...    ...
# 396025           1      0
# 396026           1      0
# 396027           1      0
# 396028           1      0
# 396029           1      0
#
# [396030 rows x 34 columns]

# %%
df = pd.concat([df.drop('purpose',axis=1),pd.get_dummies(df['purpose'],drop_first=True)],axis=1)

# %%
df = pd.concat([df.drop('initial_list_status',axis=1),pd.get_dummies(df['initial_list_status'],drop_first=True)],axis=1)

# %%
df['zip_code'] = df['address'].apply(lambda x:x.split()[-1])
df['zip_code']
# Out:
# 0         22690
# 1         05113
# 2         05113
# 3         00813
# 4         11650
#           ...
# 396025    30723
# 396026    05113
# 396027    70466
# 396028    29597
# 396029    48052
# Name: zip_code, Length: 396030, dtype: object

# %%
df['zip_code'].unique()
# Out:
# array(['22690', '05113', '00813', '11650', '30723', '70466', '29597',
#        '48052', '86630', '93700'], dtype=object)

# %%
df = pd.concat([df.drop('zip_code',axis=1),pd.get_dummies(df['zip_code'],drop_first=True)],axis=1)

# %%
df.drop('address',axis=1,inplace=True)

# %%
df.drop('year',axis=1,inplace=True)

# %%
df['earliest_cr_year'] = df['earliest_cr_line'].apply(lambda x: x.split('-')[-1])
df.drop('earliest_cr_line',axis=1,inplace=True)

# %%
df
# Out:
#         loan_amnt  term  int_rate  installment  annual_inc  loan_status  \
# 0         10000.0     0     11.44       329.48    117000.0   Fully Paid
# 1          8000.0     0     11.99       265.68     65000.0   Fully Paid
# 2         15600.0     0     10.49       506.97     43057.0   Fully Paid
# 3          7200.0     0      6.49       220.65     54000.0   Fully Paid
# 4         24375.0     1     17.27       609.33     55000.0  Charged Off
# ...           ...   ...       ...          ...         ...          ...
# 396025    10000.0     1     10.99       217.38     40000.0   Fully Paid
# 396026    21000.0     0     12.29       700.42    110000.0   Fully Paid
# 396027     5000.0     0      9.99       161.32     56500.0   Fully Paid
# 396028    21000.0     1     15.31       503.02     64000.0   Fully Paid
# 396029     2000.0     0     13.61        67.98     42996.0   Fully Paid
#
#           dti  open_acc  pub_rec  revol_bal  ...  05113  11650 22690  29597  \
# 0       26.24      16.0      0.0    36369.0  ...      0      0     1      0
# 1       22.05      17.0      0.0    20131.0  ...      1      0     0      0
# 2       12.79      13.0      0.0    11987.0  ...      1      0     0      0
# 3        2.60       6.0      0.0     5472.0  ...      0      0     0      0
# 4       33.95      13.0      0.0    24584.0  ...      0      1     0      0
# ...       ...       ...      ...        ...  ...    ...    ...   ...    ...
# 396025  15.63       6.0      0.0     1990.0  ...      0      0     0      0
# 396026  21.45       6.0      0.0    43263.0  ...      1      0     0      0
# 396027  17.56      15.0      0.0    32704.0  ...      0      0     0      0
# 396028  15.88       9.0      0.0    15704.0  ...      0      0     0      1
# 396029   8.32       3.0      0.0     4292.0  ...      0      0     0      0
#
#         30723  48052  70466  86630  93700  earliest_cr_year
# 0           0      0      0      0      0              1990
# 1           0      0      0      0      0              2004
# 2           0      0      0      0      0              2007
# 3           0      0      0      0      0              2006
# 4           0      0      0      0      0              1999
# ...       ...    ...    ...    ...    ...               ...
# 396025      1      0      0      0      0              2004
# 396026      0      0      0      0      0              2006
# 396027      0      0      1      0      0              1997
# 396028      0      0      0      0      0              1990
# 396029      0      1      0      0      0              1998
#
# [396030 rows x 53 columns]

# %% [markdown]
# ## Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
df.drop('loan_status',axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['loan_amnt', 'term', 'int_rate', 'installment', 'annual_inc', 'title',
#        'dti', 'open_acc', 'pub_rec', 'revol_bal', 'total_acc', 'mort_acc',
#        'loan_repaid', 'B', 'C', 'D', 'E', 'F', 'G', 'MORTGAGE', 'NONE',
#        'OTHER', 'OWN', 'RENT', 'Source Verified', 'Verified', 'INDIVIDUAL',
#        'JOINT', 'credit_card', 'debt_consolidation', 'educational',
#        'home_improvement', 'house', 'major_purchase', 'medical', 'moving',
#        'other', 'renewable_energy', 'small_business', 'vacation', 'wedding',
#        'w', '05113', '11650', '22690', '29597', '30723', '48052', '70466',
#        '86630', '93700', 'earliest_cr_year'],
#       dtype='object')

# %%
X=df.drop('loan_repaid',axis=1).values
y=df['loan_repaid'].values

# %%
# df = df.sample(frac=0.1,random_state=101)
print(len(df))
# Out:
# 395219

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %% [markdown]
# ## Normalizing the Data

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
X_train
# Out:
# array([[0.13924051, 0.        , 0.40085703, ..., 0.        , 0.        ,
#         0.79710145],
#        [0.26582278, 0.        , 0.28710557, ..., 0.        , 0.        ,
#         0.73913043],
#        [0.30379747, 1.        , 0.55317491, ..., 0.        , 0.        ,
#         0.8115942 ],
#        ...,
#        [0.49367089, 0.        , 0.22088041, ..., 0.        , 0.        ,
#         0.88405797],
#        [0.31139241, 0.        , 0.10050643, ..., 0.        , 0.        ,
#         0.88405797],
#        [0.2278481 , 0.        , 0.26490066, ..., 0.        , 0.        ,
#         0.82608696]])

# %% [markdown]
# ## Creating the Model

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout

# %%
model = Sequential()

model.add(Dense(78,activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(39,activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(19,activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(1,activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam')

# %%
model.fit(x=X_train, 
          y=y_train, 
          epochs=25,
          batch_size=256,
          validation_data=(X_test, y_test), 
          )
# Out:
# Epoch 1/25
# 1238/1238 [==============================] - 2s 1ms/step - loss: 0.3002 - val_loss: 0.2606
# Epoch 2/25
# 1238/1238 [==============================] - 1s 1ms/step - loss: 0.2657 - val_loss: 0.2606
# Epoch 3/25
# 1238/1238 [==============================] - 1s 1ms/step - loss: 0.2637 - val_loss: 0.2603
# Epoch 4/25
# 1238/1238 [==============================] - 2s 1ms/step - loss: 0.2626 - val_loss: 0.2592
# Epoch 5/25
# 1238/1238 [==============================] - 1s 1ms/step - loss: 0.2621 - val_loss: 0.2592
# Epoch 6/25
# 1238/1238 [==============================] - 1s 1ms/step - loss: 0.2618 - val_loss: 0.2591
# Epoch 7/25
# 1238/1238 [==============================] - 1s 1ms/step - loss: 0.2612 - val_loss: 0.2594
# Epoch 8/25
# 1238/1238 [==============================] - 1s 1ms/step - loss: 0.2613 - val_loss: 0.2591
# Epoch 9/25
# 1238/1238 [==============================] - 1s 1ms/step - loss: 0.2607 - val_loss: 0.2588
# Epoch 10/25
# 1238/1238 [==============================] - 1s 1ms/step - loss: 0.2609 - val_loss: 0.2595
# Epoch 11/25
# 1238/1238 [==============================] - 1s 1ms/step - loss: 0.2607 - val_loss: 0.2587
# Epoch 12/25
# 1238/1238 [==============================] - 1s 1ms/step - loss: 0.2604 - val_loss: 0.2585
# Epoch 13/25
# 1238/1238 [==============================] - 1s 1ms/step - loss: 0.2602 - val_loss: 0.2589
# Epoch 14/25
# 1238/1238 [==============================] - 1s 1ms/step - loss: 0.2602 - val_loss: 0.2586
# Epoch 15/25
# 1238/1238 [==============================] - 1s 1ms/step - loss: 0.2602 - val_loss: 0.2587
# Epoch 16/25
# 1238/1238 [==============================] - 1s 1ms/step - loss: 0.2597 - val_loss: 0.2585
# Epoch 17/25
# 1238/1238 [==============================] - 1s 1ms/step - loss: 0.2598 - val_loss: 0.2586
# Epoch 18/25
# 1238/1238 [==============================] - 1s 1ms/step - loss: 0.2595 - val_loss: 0.2588
# Epoch 19/25
# 1238/1238 [==============================] - 1s 1ms/step - loss: 0.2594 - val_loss: 0.2589
# Epoch 20/25
# 1238/1238 [==============================] - 1s 1ms/step - loss: 0.2595 - val_loss: 0.2585
# Epoch 21/25
# 1238/1238 [==============================] - 1s 1ms/step - loss: 0.2595 - val_loss: 0.2585
# Epoch 22/25
# 1238/1238 [==============================] - 1s 1ms/step - loss: 0.2593 - val_loss: 0.2585
# Epoch 23/25
# 1238/1238 [==============================] - 1s 1ms/step - loss: 0.2592 - val_loss: 0.2585
# Epoch 24/25
# 1238/1238 [==============================] - 1s 1ms/step - loss: 0.2593 - val_loss: 0.2585
# Epoch 25/25
# 1238/1238 [==============================] - 1s 1ms/step - loss: 0.2589 - val_loss: 0.2586

# %% [markdown]
# ## Predictions and Evaluation

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses[['loss','val_loss']].plot()
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
predictions = model.predict(X_test)
# Out:
# 2476/2476 [==============================] - 1s 306us/step

# %%
predictions = np.where(predictions > 0.5, 1,0)

# %%
predictions
# Out:
# array([[1],
#        [1],
#        [1],
#        ...,
#        [1],
#        [1],
#        [1]])

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.43      0.61     15493
#            1       0.88      1.00      0.94     63713
#
#     accuracy                           0.89     79206
#    macro avg       0.94      0.72      0.77     79206
# weighted avg       0.90      0.89      0.87     79206

# %%
import random
random.seed(101)
random_ind = random.randint(0,len(df))

new_customer = df.drop('loan_repaid',axis=1).iloc[random_ind]
new_customer
# Out:
# loan_amnt             24000.0
# term                        1
# int_rate                13.11
# installment            547.43
# annual_inc            85000.0
# dti                     10.98
# open_acc                  6.0
# pub_rec                   0.0
# revol_bal             35464.0
# total_acc                29.0
# mort_acc                  8.0
# B                           1
# C                           0
# D                           0
# E                           0
# F                           0
# G                           0
# MORTGAGE                    1
# NONE                        0
# OTHER                       0
# OWN                         0
# RENT                        0
# Source Verified             1
# Verified                    0
# INDIVIDUAL                  1
# JOINT                       0
# credit_card                 1
# debt_consolidation          0
# educational                 0
# home_improvement            0
# house                       0
# major_purchase              0
# medical                     0
# moving                      0
# other                       0
# renewable_energy            0
# small_business              0
# vacation                    0
# wedding                     0
# w                           0
# 05113                       1
# 11650                       0
# 22690                       0
# 29597                       0
# 30723                       0
# 48052                       0
# 70466                       0
# 86630                       0
# 93700                       0
# earliest_cr_year         1991
# Name: 304691, dtype: object

# %%
scaler.fit(X_train)
scaled = scaler.transform(new_customer.values.reshape(1,50))
model.predict(scaled)
# Out:
# 1/1 [==============================] - 0s 9ms/step
# array([[1.]], dtype=float32)

# %%
df['loan_repaid'][304691]
# Out:
# 1
